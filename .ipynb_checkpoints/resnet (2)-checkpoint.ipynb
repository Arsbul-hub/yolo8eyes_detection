# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
# !git clone https://github.com/Arsbul-hub/yolo8eyes_detection.git
# Out:
# Cloning into 'yolo8eyes_detection'...
# remote: Enumerating objects: 3739, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 3739 (delta 0), reused 0 (delta 0), pack-reused 3738 (from 2)
# Receiving objects: 100% (3739/3739), 154.23 MiB | 17.71 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Updating files: 100% (7924/7924), done.

# %%
# %cd yolo8eyes_detection
# Out:
# [WinError 2] Не удается найти указанный файл: 'yolo8eyes_detection'
# C:\Users\Arsbul\Desktop\yolo8eyes_detection
# C:\Users\Arsbul\Desktop\yolo8eyes_detection\venv\lib\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})

# %%
import torch

# %%
from pathlib import Path
from PIL import Image
import os
from torch.utils.data import Dataset
from torchvision import transforms


class FaceDataset(Dataset):

    def __init__(self, root):

        self.samples = []

        self.classes = set()
        for i in os.listdir(root):
            fn = i.split("_")[0]
            self.classes.add(fn)
        self.classes = list(self.classes)
        
        
        self.class_to_idx = {
            c: i
            for i, c in enumerate(self.classes)
        }

        for i in os.listdir(root):
            person = i.split("_")[0]
            self.samples.append(
                (
                    os.path.join(root, i),
                    self.class_to_idx[person]
                )
            )
        w = 160
        k = 0.43 # примерно
        self.transform = transforms.Compose([

            transforms.Resize((int(w * k),w)),

            transforms.RandomHorizontalFlip(p=0.5),

            transforms.RandomRotation(5),
            
            transforms.ColorJitter(
                brightness=0.2,
                contrast=0.2,
                saturation=0.15,
                hue=0.02
            ),

            transforms.ToTensor(),

            transforms.Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225]
            )

        ])

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):

        path, label = self.samples[idx]

        image = Image.open(path).convert("RGB")

        image = self.transform(image)

        return image, label

# %%
from torch.utils.data import Dataset, DataLoader, random_split
dataset = FaceDataset("eyes_train_resnet")

val_size = int(0.2 * len(dataset))
train_size = len(dataset) - val_size

train_dataset, val_dataset = random_split(
    dataset, 
    [train_size, val_size],
    generator=torch.Generator().manual_seed(42)  # Для воспроизводимости
)

# %%
print(dataset.class_to_idx)
print(os.listdir("eyes_train_resnet")[0])
# Out:
# {'Dwayne Johnson': 0, 'Billie Eilish': 1, 'Brad Pitt': 2, 'Zac Efron': 3, 'Hugh Jackman': 4, 'Marmik': 5, 'Elizabeth Olsen': 6, 'Natalie Portman': 7, 'Virat Kohli': 8, 'Vijay Deverakonda': 9, 'Anushka Sharma': 10, 'Amitabh Bachchan': 11, 'Courtney Cox': 12, 'Charlize Theron': 13, 'Alexandra Daddario': 14, 'Andy Samberg': 15, 'Tom Cruise': 16, 'Ellen Degeneres': 17, 'Roger Federer': 18, 'Priyanka Chopra': 19, 'Jessica Alba': 20, 'Camila Cabello': 21, 'Lisa Kudrow': 22, 'Hrithik Roshan': 23, 'Margot Robbie': 24, 'Akshay Kumar': 25, 'Claire Holt': 26, 'Alia Bhatt': 27, 'Robert Downey Jr': 28, 'Kashyap': 29, 'Henry Cavill': 30}
# Akshay Kumar_10.jpg

# %%
from torch.utils.data import DataLoader

loader = DataLoader(

    train_dataset,

    batch_size=64,

    shuffle=True,

    num_workers=0

)
loaderv = DataLoader(

    val_dataset,

    batch_size=64,

    shuffle=False,

    num_workers=0

)

# %%
import torch.nn as nn

from torchvision.models import resnet18, ResNet18_Weights


class FaceNet(nn.Module):

    def __init__(self):

        super().__init__()

        self.backbone = resnet18(weights=ResNet18_Weights.DEFAULT)

        self.backbone.fc = nn.Linear(512,512)

    def forward(self,x):

        x = self.backbone(x)

        return x

# %%
device = "cuda"
model = FaceNet().to(device)

# %%
# !pip install pytorch-metric-learning
# Out:
# Collecting pytorch-metric-learning
#   Downloading pytorch_metric_learning-2.9.0-py3-none-any.whl (127 kB)
# Requirement already satisfied: tqdm in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from pytorch-metric-learning) (4.68.3)
# Requirement already satisfied: torch>=1.6.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from pytorch-metric-learning) (2.7.1+cu118)
# Requirement already satisfied: numpy in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from pytorch-metric-learning) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from pytorch-metric-learning) (1.7.2)
# Requirement already satisfied: jinja2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.6.0->pytorch-metric-learning) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.6.0->pytorch-metric-learning) (2026.6.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.6.0->pytorch-metric-learning) (1.14.0)
# Requirement already satisfied: networkx in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.6.0->pytorch-metric-learning) (3.4.2)
# Requirement already satisfied: filelock in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.6.0->pytorch-metric-learning) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.6.0->pytorch-metric-learning) (4.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.6.0->pytorch-metric-learning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from jinja2->torch>=1.6.0->pytorch-metric-learning) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from scikit-learn->pytorch-metric-learning) (1.5.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from scikit-learn->pytorch-metric-learning) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from scikit-learn->pytorch-metric-learning) (3.6.0)
# Requirement already satisfied: colorama in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tqdm->pytorch-metric-learning) (0.4.6)
# Installing collected packages: pytorch-metric-learning
# Successfully installed pytorch-metric-learning-2.9.0
# WARNING: Ignoring invalid distribution -illow (c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages)

# %%
from pytorch_metric_learning.losses import ArcFaceLoss

# %%
loss_fn = ArcFaceLoss(

    num_classes=len(dataset.classes),

    embedding_size=512

)

# %%
optimizer = torch.optim.AdamW(
    list(model.parameters()) + list(loss_fn.parameters()),
    lr=1e-3, weight_decay=5e-4
)

# %%
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=30  # число эпох
)

# %%
epochs = 300

# %%
for epoch in range(epochs):

    model.train()
    min_loss = None
    tloss = 0.0
    val_loss = 0.0
    
    for images, labels in loader:

        images = images.to(device)

        labels = labels.to(device)

        embeddings = model(images)

        loss = loss_fn(
            embeddings,
            labels
        )
        tloss += loss.item()
        optimizer.zero_grad()

        loss.backward()

        optimizer.step()
    scheduler.step()
    if min_loss is None or tloss / len(loader) < min_loss:
        torch.save(model.state_dict(), "resnet_eyes_best.pth")
        min_loss = tloss / len(loader)
    torch.save(model.state_dict(), "resnet_eyes_last.pth")
    model.eval()
    with torch.no_grad():
        for images, labels in loaderv:
            images, labels = images.to(device), labels.to(device)
            embeddings = model(images)
            loss = loss_fn(embeddings, labels)
            val_loss += loss.item()
        
    
    print(f"TLoss: {tloss / len(loader)}, ValLoss: {val_loss / len(loaderv)}")
# Out:
# TLoss: 34.26016670227051, ValLoss: 32.40846824645996
# TLoss: 27.21201889038086, ValLoss: 32.96208190917969
# TLoss: 22.678043212890625, ValLoss: 31.61535780770438
# TLoss: 17.650117378234864, ValLoss: 27.35772705078125
# TLoss: 14.77774513244629, ValLoss: 30.441980361938477
# TLoss: 12.116437873840333, ValLoss: 21.42135660988944
# TLoss: 9.04130153656006, ValLoss: 14.266471930912562
# TLoss: 7.71689058303833, ValLoss: 17.14870629991804
# TLoss: 7.107304410934448, ValLoss: 15.993171555655342
# TLoss: 0.00021907304221282953, ValLoss: 3.407264079355303
# TLoss: 0.04621016346403597, ValLoss: 4.0309088911329
# TLoss: 0.012153867854264035, ValLoss: 4.937172932284219
# TLoss: 0.022996060649802245, ValLoss: 3.904710426926613
# TLoss: 0.07042933624237746, ValLoss: 4.460274368524551
# TLoss: 0.0014116111619605664, ValLoss: 4.667089147227151
# TLoss: 0.038451430850000176, ValLoss: 4.197345537798745
# TLoss: 0.026026688771033826, ValLoss: 4.345423647335598
# TLoss: 0.018292733790356834, ValLoss: 4.221735613686698
# TLoss: 0.022583762438133564, ValLoss: 4.011385122665421
# TLoss: 0.08533485628141704, ValLoss: 4.2269991380827765
# TLoss: 0.0025674859247602957, ValLoss: 3.976952150270535
# TLoss: 0.04539275340646037, ValLoss: 4.795753680977214
# TLoss: 0.05788260200428665, ValLoss: 4.547082811594009
# TLoss: 0.0897941024374908, ValLoss: 3.851442815420764
# TLoss: 0.19102866478564653, ValLoss: 5.075791033517037
# TLoss: 0.26698209990830946, ValLoss: 5.1667468675545285
# TLoss: 0.3643047396776817, ValLoss: 5.669053452355521
# TLoss: 0.7195812262149776, ValLoss: 13.410466057913643
# TLoss: 1.3342353184521198, ValLoss: 9.636227062770299
# TLoss: 1.408165053327484, ValLoss: 10.943152849163328
# TLoss: 1.3443571533157956, ValLoss: 8.275591791890163
# TLoss: 1.5715608703281032, ValLoss: 13.074939727783203
# TLoss: 1.4838405181531562, ValLoss: 10.031512464795794
# TLoss: 1.2722743644006551, ValLoss: 13.350379398890905
# TLoss: 1.0046191314375028, ValLoss: 11.797023977552142
# TLoss: 0.788064290796342, ValLoss: 9.243333544049944
# TLoss: 1.289895011978068, ValLoss: 9.977927446365356
# TLoss: 1.1169916257821024, ValLoss: 11.613932609558105
# TLoss: 0.9807857903651893, ValLoss: 9.392129898071289
# TLoss: 0.8820536698400849, ValLoss: 11.012909480503627
# TLoss: 1.2628659375020652, ValLoss: 10.92901086807251
# TLoss: 1.065644657239318, ValLoss: 10.349264894212995

# %%
# Out:
# Сходство: 1.0000
# Один и тот же человек

# %%
# Out:
# Collecting facenet-pytorch
# ERROR: Could not install packages due to an OSError: [WinError 5] Отказано в доступе: 'C:\\Users\\Arsbul\\Desktop\\yolo8eyes_detection\\venv\\Lib\\site-packages\\~orch\\lib\\asmjit.dll'
# Check the permissions.
#   Downloading facenet_pytorch-2.6.0-py3-none-any.whl (1.9 MB)
# Collecting torchvision<0.18.0,>=0.17.0
#   Downloading torchvision-0.17.2-cp310-cp310-win_amd64.whl (1.2 MB)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from facenet-pytorch) (2.34.2)
# Collecting torch<2.3.0,>=2.2.0
#   Downloading torch-2.2.2-cp310-cp310-win_amd64.whl (198.6 MB)
# Requirement already satisfied: tqdm<5.0.0,>=4.0.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from facenet-pytorch) (4.68.3)
# Collecting Pillow<10.3.0,>=10.2.0
#   Downloading pillow-10.2.0-cp310-cp310-win_amd64.whl (2.6 MB)
# Collecting numpy<2.0.0,>=1.24.0
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->facenet-pytorch) (2026.6.17)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (4.16.0)
# Requirement already satisfied: jinja2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (2026.6.0)
# Requirement already satisfied: networkx in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.4.2)
# Requirement already satisfied: filelock in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (3.29.4)
# Requirement already satisfied: sympy in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch<2.3.0,>=2.2.0->facenet-pytorch) (1.14.0)
# Requirement already satisfied: colorama in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tqdm<5.0.0,>=4.0.0->facenet-pytorch) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from jinja2->torch<2.3.0,>=2.2.0->facenet-pytorch) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from sympy->torch<2.3.0,>=2.2.0->facenet-pytorch) (1.3.0)
# Installing collected packages: torch, Pillow, numpy, torchvision, facenet-pytorch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.7.1+cu118
#     Uninstalling torch-2.7.1+cu118:
#       Successfully uninstalled torch-2.7.1+cu118

# %%
for i1, (img1, l1) in enumerate(dataset):
  for i2, (img2, l2) in enumerate(dataset):

    emb1 = model(img1.unsqueeze(0).to(device))
    emb2 = model(img2.unsqueeze(0).to(device))
    similarity = torch.nn.functional.cosine_similarity(
        emb1,
        emb2
    )
    print(f"Для {l1} и {l2} (инд {i2}) схожесть {similarity}")
# Out:
# Для 29 и 29 (инд 0) схожесть tensor([0.9368], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 1) схожесть tensor([0.9814], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 2) схожесть tensor([0.9889], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 3) схожесть tensor([0.9728], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 4) схожесть tensor([0.8621], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 5) схожесть tensor([0.9932], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 6) схожесть tensor([0.9877], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 7) схожесть tensor([0.9796], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 8) схожесть tensor([0.9895], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 9) схожесть tensor([0.9641], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 10) схожесть tensor([0.9648], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 11) схожесть tensor([0.9838], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 12) схожесть tensor([0.9815], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 13) схожесть tensor([0.9689], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 14) схожесть tensor([0.9480], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 15) схожесть tensor([0.9896], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 16) схожесть tensor([0.4073], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 17) схожесть tensor([0.9883], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 18) схожесть tensor([0.9881], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 19) схожесть tensor([0.9883], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 20) схожесть tensor([0.9645], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 21) схожесть tensor([0.9858], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 22) схожесть tensor([0.9630], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 23) схожесть tensor([0.9636], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 24) схожесть tensor([0.9871], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 25) схожесть tensor([0.9678], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 26) схожесть tensor([0.9790], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 27) схожесть tensor([0.9830], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 28) схожесть tensor([0.9893], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 29) схожесть tensor([0.9841], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 30) схожесть tensor([0.9870], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 31) схожесть tensor([0.9827], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 32) схожесть tensor([0.9859], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 29 (инд 33) схожесть tensor([0.6048], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 34) схожесть tensor([0.0674], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 35) схожесть tensor([0.0164], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 36) схожесть tensor([0.0272], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 37) схожесть tensor([0.0124], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 38) схожесть tensor([0.0172], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 39) схожесть tensor([0.0272], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 40) схожесть tensor([0.0296], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 41) схожесть tensor([0.0184], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 42) схожесть tensor([0.0309], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 43) схожесть tensor([0.0226], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 44) схожесть tensor([0.0208], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 45) схожесть tensor([0.0145], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 46) схожесть tensor([0.0110], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 47) схожесть tensor([0.0239], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 48) схожесть tensor([0.0151], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 49) схожесть tensor([0.0337], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 50) схожесть tensor([0.0260], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 51) схожесть tensor([0.0238], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 52) схожесть tensor([0.0241], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 53) схожесть tensor([0.0170], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 54) схожесть tensor([-0.0081], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 55) схожесть tensor([0.0179], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 56) схожесть tensor([0.0456], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 57) схожесть tensor([0.0329], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 58) схожесть tensor([0.0012], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 59) схожесть tensor([-0.0193], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 60) схожесть tensor([0.0249], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 61) схожесть tensor([0.0360], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 62) схожесть tensor([0.0238], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 63) схожесть tensor([0.0063], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 64) схожесть tensor([0.0209], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 65) схожесть tensor([0.0104], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 66) схожесть tensor([0.0294], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 67) схожесть tensor([0.0173], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 68) схожесть tensor([0.0141], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд 69) схожесть tensor([0.0207], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 9 (инд
device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 576) схожесть tensor([0.0601], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 577) схожесть tensor([0.0721], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 578) схожесть tensor([0.1053], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 579) схожесть tensor([0.0673], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 580) схожесть tensor([0.1107], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 581) схожесть tensor([0.0588], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 582) схожесть tensor([0.0925], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 583) схожесть tensor([0.0779], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 584) схожесть tensor([0.0840], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 585) схожесть tensor([0.0534], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 586) схожесть tensor([0.0495], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 587) схожесть tensor([0.0600], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 588) схожесть tensor([0.1008], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 589) схожесть tensor([0.0583], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 590) схожесть tensor([0.0853], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 591) схожесть tensor([0.1615], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 592) схожесть tensor([0.0929], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 593) схожесть tensor([0.0372], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 594) схожесть tensor([0.0531], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 595) схожесть tensor([0.1012], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 596) схожесть tensor([0.0656], device='cuda:0', grad_fn=<SumBackward1>)
# Для 29 и 13 (инд 597) схожесть tensor([0.1273], device='cuda:0', grad_fn=<SumBackward1>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 10
#       5 emb2 = model(img2.unsqueeze(0).to(device))
#       6 similarity = torch.nn.functional.cosine_similarity(
#       7     emb1,
#       8     emb2
#       9 )
# ---> 10 print(f"Для {l1} и {l2} (инд {i2}) схожесть {similarity}")
#
# File ~\Desktop\yolo8eyes_detection\venv\lib\site-packages\torch\_tensor.py:1129, in Tensor.__format__(self, format_spec)
#    1127 if self.dim() == 0 and not self.is_meta and type(self) is Tensor:
#    1128     return self.item().__format__(format_spec)
# -> 1129 return object.__format__(self, format_spec)
#
# File ~\Desktop\yolo8eyes_detection\venv\lib\site-packages\torch\_tensor.py:590, in Tensor.__repr__(self, tensor_contents)
#     586     return handle_torch_function(
#     587         Tensor.__repr__, (self,), self, tensor_contents=tensor_contents
#     588     )
#     589 # All strings are unicode in Python 3.
# --> 590 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File ~\Desktop\yolo8eyes_detection\venv\lib\site-packages\torch\_tensor_str.py:710, in _str(self, tensor_contents)
#     708 with torch.no_grad(), torch.utils._python_dispatch._disable_current_modes():
#     709     guard = torch._C._DisableFuncTorch()  # noqa: F841
# --> 710     return _str_intern(self, tensor_contents=tensor_contents)
#
# File ~\Desktop\yolo8eyes_detection\venv\lib\site-packages\torch\_tensor_str.py:631, in _str_intern(inp, tensor_contents)
#     629                     tensor_str = _tensor_str(self.to_dense(), indent)
#     630                 else:
# --> 631                     tensor_str = _tensor_str(self, indent)
#     633 if self.layout != torch.strided:
#     634     suffixes.append("layout=" + str(self.layout))
#
# File ~\Desktop\yolo8eyes_detection\venv\lib\site-packages\torch\_tensor_str.py:363, in _tensor_str(self, indent)
#     359     return _tensor_str_with_formatter(
#     360         self, indent, summarize, real_formatter, imag_formatter
#     361     )
#     362 else:
# --> 363     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     364     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File ~\Desktop\yolo8eyes_detection\venv\lib\site-packages\torch\_tensor_str.py:145, in _Formatter.__init__(self, tensor)
#     142         self.max_width = max(self.max_width, len(value_str))
#     144 else:
# --> 145     nonzero_finite_vals = torch.masked_select(
#     146         tensor_view, torch.isfinite(tensor_view) & tensor_view.ne(0)
#     147     )
#     149     if nonzero_finite_vals.numel() == 0:
#     150         # no valid number, do nothing
#     151         return
#
# KeyboardInterrupt:

# %%
model.eval()
img1, l1 = dataset[0]
img2, l2 = None, None
for n, (i, l) in enumerate(dataset):
  if l != l1:
    img2, l2 = i, l
    break
img1, l1 = dataset[1]
img2, l2 = dataset[2]
print(dataset.samples[0], dataset.samples[n], dataset[n])

emb1 = model(img1.unsqueeze(0).to(device))
emb2 = model(img2.unsqueeze(0).to(device))
similarity = torch.nn.functional.cosine_similarity(
    emb1,
    emb2
)
print(f"Для {l1} и {l2} схожесть {similarity}")
# Out:
# (PosixPath('resnet_train_aligned/Akshay Kumar/Akshay Kumar_11.jpg'), 0) (PosixPath('resnet_train_aligned/Alexandra Daddario/Alexandra Daddario_70.jpg'), 1) (tensor([[[-0.8667, -0.8667, -0.8667,  ..., -0.7176, -0.7098, -0.7098],
#          [-0.8667, -0.8667, -0.8667,  ..., -0.7333, -0.7333, -0.7333],
#          [-0.8667, -0.8667, -0.8667,  ..., -0.7569, -0.7569, -0.7569],
#          ...,
#          [ 0.7412,  0.7490,  0.7804,  ..., -0.6549, -0.6078, -0.5922],
#          [ 0.7333,  0.7490,  0.7725,  ..., -0.6471, -0.6078, -0.5922],
#          [ 0.7255,  0.7412,  0.7725,  ..., -0.6471, -0.6000, -0.5843]],
#
#         [[-0.9373, -0.9373, -0.9373,  ..., -0.8745, -0.8667, -0.8667],
#          [-0.9373, -0.9373, -0.9373,  ..., -0.8902, -0.8902, -0.8902],
#          [-0.9373, -0.9373, -0.9373,  ..., -0.9137, -0.9137, -0.9137],
#          ...,
#          [ 0.7647,  0.7725,  0.7804,  ..., -0.8039, -0.7725, -0.7569],
#          [ 0.7569,  0.7725,  0.7725,  ..., -0.7961, -0.7725, -0.7569],
#          [ 0.7490,  0.7647,  0.7725,  ..., -0.7961, -0.7647, -0.7490]],
#
#         [[-0.9765, -0.9765, -0.9765,  ..., -0.9608, -0.9529, -0.9529],
#          [-0.9765, -0.9765, -0.9765,  ..., -0.9765, -0.9765, -0.9765],
#          [-0.9765, -0.9765, -0.9765,  ..., -1.0000, -1.0000, -1.0000],
#          ...,
#          [ 0.8196,  0.8275,  0.8431,  ..., -0.9216, -0.9059, -0.8902],
#          [ 0.8118,  0.8275,  0.8353,  ..., -0.9137, -0.9059, -0.9059],
#          [ 0.8039,  0.8196,  0.8353,  ..., -0.9137, -0.9137, -0.8980]]]), 1)
# Для 0 и 0 схожесть tensor([0.7782], device='cuda:0', grad_fn=<SumBackward1>)

# %%
model.eval()
# Out:
# FaceNet(
#   (backbone): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=512, bias=True)
#   )
# )

# %%
w = 160
k = 0.43 # примерно
transform = transforms.Compose([

    transforms.Resize((int(w * k),w)),

    transforms.ToTensor(),

    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )

])

ref = transform(Image.open("./ethalon.jpg").convert("RGB"))
an = transform(Image.open("./another_eyes.jpg").convert("RGB"))
test = transform(Image.open("./test.jpg").convert("RGB"))
emb1 = model(ref.unsqueeze(0).to(device))
emb2 = model(an.unsqueeze(0).to(device))
emb3 = model(test.unsqueeze(0).to(device))
similarity1 = torch.nn.functional.cosine_similarity(
    emb3,emb1

)
similarity2 = torch.nn.functional.cosine_similarity(
    emb1,
    emb2
)
similarity3 = torch.nn.functional.cosine_similarity(
    emb2,
    emb3
)
print(f"sim: {similarity1}")
print(f"an: {similarity2}")
print(f"an: {similarity3}")
# Out:
# sim: tensor([0.9461], device='cuda:0', grad_fn=<SumBackward1>)
# an: tensor([0.3213], device='cuda:0', grad_fn=<SumBackward1>)
# an: tensor([0.3882], device='cuda:0', grad_fn=<SumBackward1>)

# %%
similarity
# Out:
# tensor([1.], device='cuda:0', grad_fn=<SumBackward1>)
