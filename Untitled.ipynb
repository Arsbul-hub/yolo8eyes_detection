# %%
from ultralytics import YOLO

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 models = list_zoo_models()
#       2 print(models)
#
# NameError: name 'list_zoo_models' is not defined

# %%
# Load a pretrained YOLO26n model
model = YOLO("./d.pt")

# Train the model on the COCO8 dataset for 100 epochs

# %%
train_results = model.train(
    data="./trainv2/data.yaml",  # Path to dataset configuration file
    epochs=1,  # Number of training epochs
    imgsz=1024,  # Image size for training
    device="cpu",  # Device to run on (e.g., 'cpu', 0, [0,1,2,3])
)

# %%
# Evaluate the model's performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.4.83  Python-3.11.0 torch-2.12.1+cpu CPU (Intel Core i5-1035G1 1.00GHz)
# val: Fast image access  (ping: 0.30.1 ms, read: 147.931.6 MB/s, size: 291.5 KB)
# val: Scanning C:\Users\Arsbul\Desktop\yolo8eyes_detection\trainv2\val.cache... 0 images, 319 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 319/319  0.0s
# WARNING Labels are missing or empty in C:\Users\Arsbul\Desktop\yolo8eyes_detection\trainv2\val.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 15% ━╸────────── 3/20 12.4s/it 19.1s<3:30
# KeyboardInterrupt

# %%
# Perform object detection on an image
results = model("./trainv2/train/images/1b8f73dd-00dacaae3139e2af.jpg")  # Predict on an image
results[0].show()  # Display results
# Out:
# image 1/1 C:\Users\Arsbul\Desktop\yolo8eyes_detection\trainv2\train\images\1b8f73dd-00dacaae3139e2af.jpg: 1024x768 (no detections), 283.1ms
# Speed: 6.9ms preprocess, 283.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1024, 768)

# %%
import cv2
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Ошибка: не удалось открыть видеопоток")
    exit()

# 3. Настройки для детекции (опционально)
# Можно передавать параметры прямо в model() или задать глобально:
# model.conf = 0.25   # порог уверенности
# model.iou = 0.45    # порог NMS

while True:
    # 4. Чтение кадра
    ret, frame = cap.read()
    if not ret:
        print("Поток завершён")
        break


    results = model(frame)  # можно добавить параметры: model(frame, conf=0.25, iou=0.45)
   

    #    Метод plot() возвращает изображение в формате numpy (BGR)
    annotated_frame = results[0].plot()

    cv2.imshow("YOLOv8 Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 9. Освобождаем ресурсы
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 eyes, 97.3ms
# Speed: 45.7ms preprocess, 97.3ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 99.5ms
# Speed: 6.1ms preprocess, 99.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 98.8ms
# Speed: 2.9ms preprocess, 98.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 79.5ms
# Speed: 3.1ms preprocess, 79.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 78.6ms
# Speed: 1.8ms preprocess, 78.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 77.1ms
# Speed: 2.4ms preprocess, 77.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 85.5ms
# Speed: 1.7ms preprocess, 85.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 74.8ms
# Speed: 3.5ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 77.9ms
# Speed: 1.9ms preprocess, 77.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 74.0ms
# Speed: 1.7ms preprocess, 74.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 72.0ms
# Speed: 1.9ms preprocess, 72.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 76.3ms
# Speed: 2.7ms preprocess, 76.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 73.2ms
# Speed: 2.1ms preprocess, 73.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 78
0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 98.8ms
# Speed: 3.5ms preprocess, 98.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 eyess, 91.2ms
# Speed: 2.5ms preprocess, 91.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 100.2ms
# Speed: 3.4ms preprocess, 100.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 90.6ms
# Speed: 2.3ms preprocess, 90.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 99.2ms
# Speed: 3.7ms preprocess, 99.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 eyess, 92.3ms
# Speed: 4.3ms preprocess, 92.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 95.0ms
# Speed: 2.9ms preprocess, 95.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 97.9ms
# Speed: 2.3ms preprocess, 97.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 eyess, 90.4ms
# Speed: 2.3ms preprocess, 90.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 91.4ms
# Speed: 2.0ms preprocess, 91.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 eyess, 99.0ms
# Speed: 2.2ms preprocess, 99.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 108.6ms
# Speed: 2.3ms preprocess, 108.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 eyess, 107.6ms
# Speed: 2.9ms preprocess, 107.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 174.8ms
# Speed: 2.6ms preprocess, 174.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 91.2ms
# Speed: 2.4ms preprocess, 91.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 97.4ms
# Speed: 2.5ms preprocess, 97.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 92.4ms
# Speed: 2.0ms preprocess, 92.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 87.7ms
# Speed: 2.9ms preprocess, 87.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 79.2ms
# Speed: 1.7ms preprocess, 79.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 74.0ms
# Speed: 2.3ms preprocess, 74.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 79.6ms
# Speed: 1.8ms preprocess, 79.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 75.5ms
# Speed: 2.1ms preprocess, 75.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 80.3ms
# Speed: 3.0ms preprocess, 80.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 77.1ms
# Speed: 1.7ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 74.7ms
# Speed: 1.9ms preprocess, 74.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 79.2ms
# Speed: 2.7ms preprocess, 79.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 76.1ms
# Speed: 1.9ms preprocess, 76.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 72.8ms
# Speed: 2.0ms preprocess, 72.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 82.8ms
# Speed: 1.7ms preprocess, 82.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 eyess, 71.1ms
# Speed: 2.0ms preprocess, 71.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 72.2ms
# Speed: 2.6ms preprocess, 72.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 78.1ms
# Speed: 1.7ms preprocess, 78.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 77.7ms
# Speed: 1.7ms preprocess, 77.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 74.3ms
# Speed: 1.9ms preprocess, 74.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 73.9ms
# Speed: 2.3ms preprocess, 73.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 81.0ms
# Speed: 2.1ms preprocess, 81.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 72.8ms
# Speed: 2.5ms preprocess, 72.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 75.3ms
# Speed: 2.0ms preprocess, 75.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 93.4ms
# Speed: 2.6ms preprocess, 93.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 104.5ms
# Speed: 2.1ms preprocess, 104.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 100.5ms
# Speed: 2.2ms preprocess, 100.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 95.6ms
# Speed: 2.0ms preprocess, 95.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 98.8ms
# Speed: 2.2ms preprocess, 98.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 99.5ms
# Speed: 2.1ms preprocess, 99.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 90.7ms
# Speed: 2.0ms preprocess, 90.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 102.5ms
# Speed: 2.0ms preprocess, 102.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 92.0ms
# Speed: 2.1ms preprocess, 92.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 173.1ms
# Speed: 2.0ms preprocess, 173.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 100.6ms
# Speed: 2.1ms preprocess, 100.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 100.7ms
# Speed: 2.4ms preprocess, 100.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 105.1ms
# Speed: 2.3ms preprocess, 105.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 99.6ms
# Speed: 2.1ms preprocess, 99.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 92.0ms
# Speed: 2.1ms preprocess, 92.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 98.4ms
# Speed: 2.2ms preprocess, 98.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 97.6ms
# Speed: 1.9ms preprocess, 97.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 89.1ms
# Speed: 2.2ms preprocess, 89.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 79.8ms
# Speed: 1.6ms preprocess, 79.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 eyes, 83.3ms
# Speed: 1.9ms preprocess, 83.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Export the model to ONNX format for deployment
path = model.export(format="onnx")  # Returns the path to the exported model
