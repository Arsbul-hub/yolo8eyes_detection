# %%
# !git clone https://github.com/Megvii-BaseDetection/YOLOX.git
# Out:
# Cloning into 'YOLOX'...
# warning: the following paths have collided (e.g. case-sensitive paths
# on a case-insensitive filesystem) and only one from the same
# colliding group is in the working tree:
#
#   'demo/ncnn/android/app/src/main/java/com/megvii/yoloXncnn/YOLOXncnn.java'
#   'demo/ncnn/android/app/src/main/java/com/megvii/yoloXncnn/yoloXncnn.java'

# %%
# %cd YOLOX
# Out:
# C:\Users\Arsbul\Desktop\yolo8eyes_detection\YOLOX
# C:\Users\Arsbul\Desktop\yolo8eyes_detection\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install numpy wheel
# !pip install -r requirements.txt
# !pip install -v -e .
# Out:
#     Running command python setup.py egg_info
#     WARNING: The wheel package is not available.
#     running egg_info
#     creating C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-kgffj4pz\yolox.egg-info
#     writing C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-kgffj4pz\yolox.egg-info\PKG-INFO
#     writing dependency_links to C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-kgffj4pz\yolox.egg-info\dependency_links.txt
#     writing requirements to C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-kgffj4pz\yolox.egg-info\requires.txt
#     writing top-level names to C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-kgffj4pz\yolox.egg-info\top_level.txt
#     writing manifest file 'C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-kgffj4pz\yolox.egg-info\SOURCES.txt'
#     reading manifest file 'C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-kgffj4pz\yolox.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching '*.cu' under directory 'yolox'
#     warning: no files found matching '*.cuh' under directory 'yolox'
#     warning: no files found matching '*.cc' under directory 'yolox'
#     adding license file 'LICENSE'
#     writing manifest file 'C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-kgffj4pz\yolox.egg-info\SOURCES.txt'
#     Running command 'C:\Users\Arsbul\Desktop\yolo8eyes_detection\venv\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Arsbul\\Desktop\\yolo8eyes_detection\\YOLOX\\setup.py'"'"'; __file__='"'"'C:\\Users\\Arsbul\\Desktop\\yolo8eyes_detection\\YOLOX\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' develop --no-deps
#     WARNING: The wheel package is not available.
#     running develop
#     running egg_info
#     writing yolox.egg-info\PKG-INFO
#     writing dependency_links to yolox.egg-info\dependency_links.txt
#     writing requirements to yolox.egg-info\requires.txt
#     writing top-level names to yolox.egg-info\top_level.txt
#     reading manifest file 'yolox.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching '*.cu' under directory 'yolox'
#     warning: no files found matching '*.cuh' under directory 'yolox'
#     warning: no files found matching '*.cc' under directory 'yolox'
#     adding license file 'LICENSE'
#     writing manifest file 'yolox.egg-info\SOURCES.txt'
#     running build_ext
#     Creating c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages\yolox.egg-link (link to .)
#     Adding yolox 0.3.0 to easy-install.pth file
#
#     Installed c:\users\arsbul\desktop\yolo8eyes_detection\yolox
# Using pip 21.2.3 from C:\Users\Arsbul\Desktop\yolo8eyes_detection\venv\lib\site-packages\pip (python 3.10)
# Obtaining file:///C:/Users/Arsbul/Desktop/yolo8eyes_detection/YOLOX
# Requirement already satisfied: numpy in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (2.2.6)
# Requirement already satisfied: torch>=1.7 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (2.12.1)
# Requirement already satisfied: opencv_python in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (5.0.0.93)
# Requirement already satisfied: loguru in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.7.3)
# Requirement already satisfied: tqdm in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (4.68.3)
# Requirement already satisfied: torchvision in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.27.1)
# Requirement already satisfied: thop in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.1.1.post2209072238)
# Requirement already satisfied: ninja in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (1.13.0)
# Requirement already satisfied: tabulate in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.10.0)
# Requirement already satisfied: psutil in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (7.2.2)
# Requirement already satisfied: tensorboard in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (2.21.0)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (2.0.11)
# Requirement already satisfied: onnx>=1.13.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (1.22.0)
# Requirement already satisfied: onnx-simplifier==0.4.10 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.4.10)
# Requirement already satisfied: rich in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx-simplifier==0.4.10->yolox==0.3.0) (15.0.0)
# Requirement already satisfied: typing_extensions>=4.15.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx>=1.13.0->yolox==0.3.0) (4.16.0)
# Requirement already satisfied: ml_dtypes>=0.5.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx>=1.13.0->yolox==0.3.0) (0.5.4)
# Requirement already satisfied: protobuf>=4.25.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx>=1.13.0->yolox==0.3.0) (7.35.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (3.4.2)
# Requirement already satisfied: setuptools<82 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (57.4.0)
# Requirement already satisfied: jinja2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (2026.6.0)
# Requirement already satisfied: filelock in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (3.29.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.7->yolox==0.3.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from jinja2->torch>=1.7->yolox==0.3.0) (3.0.3)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from loguru->yolox==0.3.0) (1.2.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from loguru->yolox==0.3.0) (0.4.6)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from rich->onnx-simplifier==0.4.10->yolox==0.3.0) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from rich->onnx-simplifier==0.4.10->yolox==0.3.0) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->onnx-simplifier==0.4.10->yolox==0.3.0) (0.1.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (3.10.2)
# Requirement already satisfied: packaging in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (26.2)
# Requirement already satisfied: grpcio<2.0,>=1.74.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (1.81.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (2.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (3.1.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (0.7.2)
# Requirement already satisfied: pillow in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (12.3.0)
# Installing collected packages: yolox
#   Attempting uninstall: yolox
#     Found existing installation: yolox 0.3.0
#     Uninstalling yolox-0.3.0:
#       Removing file or directory c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages\yolox.egg-link
#       Removing pth entries from c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages\easy-install.pth:
#       Removing entry: c:\users\arsbul\desktop\yolo8eyes_detection\yolox
#       Successfully uninstalled yolox-0.3.0
#   Running setup.py develop for yolox
# Successfully installed yolox-0.3.0
# Requirement already satisfied: numpy in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (2.2.6)
# Collecting wheel
#   Using cached wheel-0.47.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: packaging>=24.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from wheel) (26.2)
# Installing collected packages: wheel
# Successfully installed wheel-0.47.0
# Requirement already satisfied: numpy in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 2)) (2.2.6)
# Requirement already satisfied: torch>=1.7 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 3)) (2.12.1)
# Requirement already satisfied: opencv_python in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 4)) (5.0.0.93)
# Requirement already satisfied: loguru in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 5)) (0.7.3)
# Requirement already satisfied: tqdm in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 6)) (4.68.3)
# Requirement already satisfied: torchvision in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 7)) (0.27.1)
# Requirement already satisfied: thop in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 8)) (0.1.1.post2209072238)
# Requirement already satisfied: ninja in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 9)) (1.13.0)
# Requirement already satisfied: tabulate in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 10)) (0.10.0)
# Requirement already satisfied: psutil in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 11)) (7.2.2)
# Requirement already satisfied: tensorboard in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 12)) (2.21.0)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 16)) (2.0.11)
# Requirement already satisfied: onnx>=1.13.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 17)) (1.22.0)
# Requirement already satisfied: onnx-simplifier==0.4.10 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from -r requirements.txt (line 18)) (0.4.10)
# Requirement already satisfied: rich in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx-simplifier==0.4.10->-r requirements.txt (line 18)) (15.0.0)
# Requirement already satisfied: jinja2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: filelock in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->-r requirements.txt (line 3)) (3.29.4)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->-r requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->-r requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: setuptools<82 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->-r requirements.txt (line 3)) (57.4.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->-r requirements.txt (line 3)) (4.16.0)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->-r requirements.txt (line 3)) (2026.6.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from loguru->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from loguru->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torchvision->-r requirements.txt (line 7)) (12.3.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (3.10.2)
# Requirement already satisfied: grpcio<2.0,>=1.74.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (1.81.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (3.1.8)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (7.35.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (0.7.2)
# Requirement already satisfied: packaging in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (26.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->-r requirements.txt (line 12)) (2.4.0)
# Requirement already satisfied: ml_dtypes>=0.5.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx>=1.13.0->-r requirements.txt (line 17)) (0.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.7->-r requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 12)) (3.0.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from rich->onnx-simplifier==0.4.10->-r requirements.txt (line 18)) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from rich->onnx-simplifier==0.4.10->-r requirements.txt (line 18)) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->onnx-simplifier==0.4.10->-r requirements.txt (line 18)) (0.1.2)
# Using pip 21.2.3 from C:\Users\Arsbul\Desktop\yolo8eyes_detection\venv\lib\site-packages\pip (python 3.10)
# Obtaining file:///C:/Users/Arsbul/Desktop/yolo8eyes_detection/YOLOX
# Requirement already satisfied: numpy in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (2.2.6)
# Requirement already satisfied: torch>=1.7 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (2.12.1)
# Requirement already satisfied: opencv_python in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (5.0.0.93)
# Requirement already satisfied: loguru in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.7.3)
# Requirement already satisfied: tqdm in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (4.68.3)
# Requirement already satisfied: torchvision in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.27.1)
# Requirement already satisfied: thop in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.1.1.post2209072238)
# Requirement already satisfied: ninja in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (1.13.0)
# Requirement already satisfied: tabulate in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.10.0)
# Requirement already satisfied: psutil in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (7.2.2)
# Requirement already satisfied: tensorboard in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (2.21.0)
# Requirement already satisfied: pycocotools>=2.0.2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (2.0.11)
# Requirement already satisfied: onnx>=1.13.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (1.22.0)
# Requirement already satisfied: onnx-simplifier==0.4.10 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from yolox==0.3.0) (0.4.10)
# Requirement already satisfied: rich in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx-simplifier==0.4.10->yolox==0.3.0) (15.0.0)
# Requirement already satisfied: ml_dtypes>=0.5.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx>=1.13.0->yolox==0.3.0) (0.5.4)
# Requirement already satisfied: protobuf>=4.25.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx>=1.13.0->yolox==0.3.0) (7.35.1)
# Requirement already satisfied: typing_extensions>=4.15.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from onnx>=1.13.0->yolox==0.3.0) (4.16.0)
# Requirement already satisfied: filelock in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (3.29.4)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (3.4.2)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (2026.6.0)
# Requirement already satisfied: setuptools<82 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (57.4.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from torch>=1.7->yolox==0.3.0) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.7->yolox==0.3.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from jinja2->torch>=1.7->yolox==0.3.0) (3.0.3)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from loguru->yolox==0.3.0) (1.2.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from loguru->yolox==0.3.0) (0.4.6)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from rich->onnx-simplifier==0.4.10->yolox==0.3.0) (2.20.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from rich->onnx-simplifier==0.4.10->yolox==0.3.0) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->onnx-simplifier==0.4.10->yolox==0.3.0) (0.1.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (0.7.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (2.4.0)
# Requirement already satisfied: packaging in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (26.2)
# Requirement already satisfied: pillow in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (12.3.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (3.1.8)
# Requirement already satisfied: grpcio<2.0,>=1.74.0 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages (from tensorboard->yolox==0.3.0) (3.10.2)
# Installing collected packages: yolox
#   Attempting uninstall: yolox
#     Found existing installation: yolox 0.3.0
#     Uninstalling yolox-0.3.0:
#       Removing file or directory c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages\yolox.egg-link
#       Removing pth entries from c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages\easy-install.pth:
#       Removing entry: c:\users\arsbul\desktop\yolo8eyes_detection\yolox
#       Successfully uninstalled yolox-0.3.0
#   Running setup.py develop for yolox
# Successfully installed yolox-0.3.0
#     Running command python setup.py egg_info
#     running egg_info
#     creating C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-jshkshne\yolox.egg-info
#     writing C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-jshkshne\yolox.egg-info\PKG-INFO
#     writing dependency_links to C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-jshkshne\yolox.egg-info\dependency_links.txt
#     writing requirements to C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-jshkshne\yolox.egg-info\requires.txt
#     writing top-level names to C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-jshkshne\yolox.egg-info\top_level.txt
#     writing manifest file 'C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-jshkshne\yolox.egg-info\SOURCES.txt'
#     reading manifest file 'C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-jshkshne\yolox.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching '*.cu' under directory 'yolox'
#     warning: no files found matching '*.cuh' under directory 'yolox'
#     warning: no files found matching '*.cc' under directory 'yolox'
#     adding license file 'LICENSE'
#     writing manifest file 'C:\Users\Arsbul\AppData\Local\Temp\pip-pip-egg-info-jshkshne\yolox.egg-info\SOURCES.txt'
#     Running command 'C:\Users\Arsbul\Desktop\yolo8eyes_detection\venv\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\Arsbul\\Desktop\\yolo8eyes_detection\\YOLOX\\setup.py'"'"'; __file__='"'"'C:\\Users\\Arsbul\\Desktop\\yolo8eyes_detection\\YOLOX\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' develop --no-deps
#     running develop
#     running egg_info
#     writing yolox.egg-info\PKG-INFO
#     writing dependency_links to yolox.egg-info\dependency_links.txt
#     writing requirements to yolox.egg-info\requires.txt
#     writing top-level names to yolox.egg-info\top_level.txt
#     reading manifest file 'yolox.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching '*.cu' under directory 'yolox'
#     warning: no files found matching '*.cuh' under directory 'yolox'
#     warning: no files found matching '*.cc' under directory 'yolox'
#     adding license file 'LICENSE'
#     writing manifest file 'yolox.egg-info\SOURCES.txt'
#     running build_ext
#     Creating c:\users\arsbul\desktop\yolo8eyes_detection\venv\lib\site-packages\yolox.egg-link (link to .)
#     Adding yolox 0.3.0 to easy-install.pth file
#
#     Installed c:\users\arsbul\desktop\yolo8eyes_detection\yolox

# %%
# !python -c "import torch; print(torch.__version__); print(torch.version.cuda); print(torch.cuda.is_available())"
# Out:
# 2.7.1+cu118
# 11.8
# True

# %%
# !python tools/demo.py webcam -f exps/example/custom/nano.py -c YOLOX_outputs/nano/best_ckpt.pth --device gpu

# %%
# !python tools/train.py -f exps/example/custom/nano.py -d 1 -b 2 --fp16 -o -c weights/yolox_nano.pth

# %%
# !python tools/export_onnx.py \
-f exps/example/custom/nano.py \
-c YOLOX_outputs/nano/best_ckpt.pth \
-o 11 \
--output-name eye_detector.onnx
# Out:
# 2026-07-03 12:04:37.363 | INFO     | __main__:main:64 - args value: Namespace(output_name='eye_detector.onnx', input='images', output='output', opset=11, batch_size=1, dynamic=False, no_onnxsim=False, exp_file='exps/example/custom/nano.py', experiment_name=None, name=None, ckpt='YOLOX_outputs/nano/best_ckpt.pth', opts=[], decode_in_inference=False)
# 2026-07-03 12:04:37.511 | INFO     | __main__:main:88 - loading checkpoint done.
# 2026-07-03 12:04:39.238 | INFO     | __main__:main:101 - generated onnx model named eye_detector.onnx
# 2026-07-03 12:04:39.957 | INFO     | __main__:main:112 - generated simplified onnx model named eye_detector.onnx

# %%
#!/usr/bin/env python3
# Copyright (c) Megvii, Inc. and its affiliates.

import argparse
import os

import cv2
import numpy as np

import onnxruntime

from yolox.data.data_augment import preproc as preprocess
from yolox.data.datasets import COCO_CLASSES
from yolox.utils import multiclass_nms, demo_postprocess, vis



if __name__ == '__main__':
    args = make_parser().parse_args()

    input_shape = (640, 640)
    origin_img = cv2.imread(args.image_path)
    img, ratio = preprocess(origin_img, input_shape)

    session = onnxruntime.InferenceSession(args.model)

    ort_inputs = {session.get_inputs()[0].name: img[None, :, :, :]}
    output = session.run(None, ort_inputs)
    predictions = demo_postprocess(output[0], input_shape)[0]

    boxes = predictions[:, :4]
    scores = predictions[:, 4:5] * predictions[:, 5:]

    boxes_xyxy = np.ones_like(boxes)
    boxes_xyxy[:, 0] = boxes[:, 0] - boxes[:, 2]/2.
    boxes_xyxy[:, 1] = boxes[:, 1] - boxes[:, 3]/2.
    boxes_xyxy[:, 2] = boxes[:, 0] + boxes[:, 2]/2.
    boxes_xyxy[:, 3] = boxes[:, 1] + boxes[:, 3]/2.
    boxes_xyxy /= ratio
    dets = multiclass_nms(boxes_xyxy, scores, nms_thr=0.45, score_thr=0.1)
    if dets is not None:
        final_boxes, final_scores, final_cls_inds = dets[:, :4], dets[:, 4], dets[:, 5]
        origin_img = vis(origin_img, final_boxes, final_scores, final_cls_inds,
                         conf=args.score_thr, class_names=COCO_CLASSES)

    mkdir(args.output_dir)
    output_path = os.path.join(args.output_dir, os.path.basename(args.image_path))
    cv2.imwrite(output_path, origin_img)

# %%
import cv2
import onnxruntime
import numpy as np
session = onnxruntime.InferenceSession(
    "eye_detector.onnx",
    providers=["CUDAExecutionProvider"]
)
from yolox.data.data_augment import preproc as preprocess
# from yolox.data.datasets import COCO_CLASSES
from yolox.utils import mkdir, multiclass_nms, demo_postprocess, vis

CLASSES = ["eyes"]

input_shape = (1024, 1024)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    img, ratio = preprocess(frame, input_shape)


    ort_inputs = {session.get_inputs()[0].name: img[None, :, :, :]}
    output = session.run(None, ort_inputs)
    predictions = demo_postprocess(output[0], input_shape)[0]

    boxes = predictions[:, :4]
    scores = predictions[:, 4:5] * predictions[:, 5:]

    boxes_xyxy = np.ones_like(boxes)
    boxes_xyxy[:, 0] = boxes[:, 0] - boxes[:, 2]/2.
    boxes_xyxy[:, 1] = boxes[:, 1] - boxes[:, 3]/2.
    boxes_xyxy[:, 2] = boxes[:, 0] + boxes[:, 2]/2.
    boxes_xyxy[:, 3] = boxes[:, 1] + boxes[:, 3]/2.
    boxes_xyxy /= ratio
    dets = multiclass_nms(boxes_xyxy, scores, nms_thr=0.45, score_thr=0.1)
    if dets is not None:
        final_boxes, final_scores, final_cls_inds = dets[:, :4], dets[:, 4], dets[:, 5]
        frame = vis(frame, final_boxes, final_scores, final_cls_inds,
                         conf=0.3, class_names=CLASSES)
    # 1. Подготовка изображения
    # 2. session.run(...)
    # 3. NMS
    # 4. Рисование
    
    cv2.imshow("Camera", frame)

    if cv2.waitKey(1) == 27:
        break
# Out:
# C:\Users\Arsbul\Desktop\yolo8eyes_detection\venv\lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      19 img, ratio = preprocess(frame, input_shape)
#      22 ort_inputs = {session.get_inputs()[0].name: img[None, :, :, :]}
# ---> 23 output = session.run(None, ort_inputs)
#      24 predictions = demo_postprocess(output[0], input_shape)[0]
#      26 boxes = predictions[:, :4]
#
# File ~\Desktop\yolo8eyes_detection\venv\lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:287, in Session.run(self, output_names, input_feed, run_options)
#     285     output_names = [output.name for output in self._outputs_meta]
#     286 try:
# --> 287     return self._sess.run(output_names, input_feed, run_options)
#     288 except C.EPFail as err:
#     289     if self._enable_fallback:
#
# KeyboardInterrupt:
